# %% [markdown]
# <a href="https://colab.research.google.com/github/henriquezacarias/learngit/blob/master/my_first_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
print('Hello word!')
# Out:
# Hello word!

# %%
pd.read_excel('sample_data/saida.xls')
# Out:
#       NUM_PESSOA  ... SEQ_MUNICIPI
# 0             27  ...          193
# 1             33  ...          143
# 2             39  ...          143
# 3             43  ...          103
# 4           1922  ...          167
# ...          ...  ...          ...
# 1763       77604  ...          183
# 1764       77618  ...          194
# 1765       77628  ...          107
# 1766       77630  ...          143
# 1767       77642  ...          140
#
# [1768 rows x 26 columns]
